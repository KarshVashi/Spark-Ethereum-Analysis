# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('avg_price.csv')

# %%
df.head()
# Out:
#       Date  Average gas price
# 0  01/2016       5.659627e+10
# 1  01/2017       2.250757e+10
# 2  01/2018       5.210606e+10
# 3  01/2019       1.395446e+10
# 4  02/2016       6.918068e+10

# %%
plt.figure(figsize = (30,10))

x=df['Date']
y=df['Average gas price']
plt.xlabel('Date in Month and Year')
plt.ylabel('Average gas price')
plt.xticks(rotation=90)

plt.plot(x,y)
